# %%
import tensorflow as tf 
from tensorflow.keras import layers
from tensorflow.keras import regularizers

# %%
# !pip install git+https://github.com/tensorflow/docs
# Out:
# Collecting git+https://github.com/tensorflow/docs
#   Cloning https://github.com/tensorflow/docs to /private/var/folders/zf/p75y8jj52c72dh5cv6ys92pm0000gn/T/pip-req-build-v4ech38r
#   Running command git clone --filter=blob:none --quiet https://github.com/tensorflow/docs /private/var/folders/zf/p75y8jj52c72dh5cv6ys92pm0000gn/T/pip-req-build-v4ech38r
#   Resolved https://github.com/tensorflow/docs to commit b8d090113861d46bf007c087c089cb8442d41060
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: astor in /Users/ignaciomoyaredondo/opt/anaconda3/lib/python3.9/site-packages (from tensorflow-docs==0.0.0.dev0) (0.8.1)
# Requirement already satisfied: absl-py in /Users/ignaciomoyaredondo/opt/anaconda3/lib/python3.9/site-packages (from tensorflow-docs==0.0.0.dev0) (1.1.0)
# Requirement already satisfied: jinja2 in /Users/ignaciomoyaredondo/opt/anaconda3/lib/python3.9/site-packages (from tensorflow-docs==0.0.0.dev0) (2.11.3)
# Requirement already satisfied: nbformat in /Users/ignaciomoyaredondo/opt/anaconda3/lib/python3.9/site-packages (from tensorflow-docs==0.0.0.dev0) (5.5.0)
# Requirement already satisfied: protobuf<3.20,>=3.12.0 in /Users/ignaciomoyaredondo/opt/anaconda3/lib/python3.9/site-packages (from tensorflow-docs==0.0.0.dev0) (3.19.6)
# Requirement already satisfied: pyyaml in /Users/ignaciomoyaredondo/opt/anaconda3/lib/python3.9/site-packages (from tensorflow-docs==0.0.0.dev0) (6.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/ignaciomoyaredondo/opt/anaconda3/lib/python3.9/site-packages (from jinja2->tensorflow-docs==0.0.0.dev0) (2.0.1)
# Requirement already satisfied: jsonschema>=2.6 in /Users/ignaciomoyaredondo/opt/anaconda3/lib/python3.9/site-packages (from nbformat->tensorflow-docs==0.0.0.dev0) (4.16.0)
# Requirement already satisfied: jupyter_core in /Users/ignaciomoyaredondo/opt/anaconda3/lib/python3.9/site-packages (from nbformat->tensorflow-docs==0.0.0.dev0) (4.11.1)
# Requirement already satisfied: fastjsonschema in /Users/ignaciomoyaredondo/opt/anaconda3/lib/python3.9/site-packages (from nbformat->tensorflow-docs==0.0.0.dev0) (2.16.2)
# Requirement already satisfied: traitlets>=5.1 in /Users/ignaciomoyaredondo/opt/anaconda3/lib/python3.9/site-packages (from nbformat->tensorflow-docs==0.0.0.dev0) (5.1.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/ignaciomoyaredondo/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat->tensorflow-docs==0.0.0.dev0) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/ignaciomoyaredondo/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat->tensorflow-docs==0.0.0.dev0) (21.4.0)

# %%
import tensorflow_docs as tfdocs
import tensorflow_docs.modeling
import tensorflow_docs.plots

# %%
from  IPython import display
from matplotlib import pyplot as plt

import numpy as np

import pathlib
import shutil
import tempfile

# %%
logdir = pathlib.Path(tempfile.mkdtemp())/"tensorboard_logs"
shutil.rmtree(logdir, ignore_errors=True)

# %%
gz = tf.keras.utils.get_file('HIGGS.csv.gz', 'http://mlphysics.ics.uci.edu/data/higgs/HIGGS.csv.gz')
# Out:
# Downloading data from http://mlphysics.ics.uci.edu/data/higgs/HIGGS.csv.gz
# 2816407858/2816407858 [==============================] - 1153s 0us/step

# %%
FEATURES = 28
ds = tf.data.experimental.CsvDataset(gz,[float(),]*(FEATURES+1), compression_type="GZIP")
# Out:
# 2022-11-13 11:01:03.456609: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def pack_row(*row):
    label = row[0]
    features = tf.stack(row[1:],1)
    return features, label

# %%
packed_ds = ds.batch(10000).map(pack_row).unbatch()

# %%
for features,label in packed_ds.batch(1000).take(1):
    print(features[0])
    plt.hist(features.numpy().flatten(), bins = 101)
# Out:
# tf.Tensor(
# [ 0.8692932  -0.6350818   0.22569026  0.32747006 -0.6899932   0.75420225
#  -0.24857314 -1.0920639   0.          1.3749921  -0.6536742   0.9303491
#   1.1074361   1.1389043  -1.5781983  -1.0469854   0.          0.65792954
#  -0.01045457 -0.04576717  3.1019614   1.35376     0.9795631   0.97807616
#   0.92000484  0.72165745  0.98875093  0.87667835], shape=(28,), dtype=float32)

# %%
N_VALIDATION = int(1e3)
N_TRAIN = int(1e4)
BUFFER_SIZE = int(1e4)
BATCH_SIZE = 500
STEPS_PER_EPOCH = N_TRAIN//BATCH_SIZE

# %%
validate_ds = packed_ds.take(N_VALIDATION).cache()
train_ds = packed_ds.skip(N_VALIDATION).take(N_TRAIN).cache()

# %%
train_ds
# Out:
# <CacheDataset element_spec=(TensorSpec(shape=(28,), dtype=tf.float32, name=None), TensorSpec(shape=(), dtype=tf.float32, name=None))>

# %%
validate_ds = validate_ds.batch(BATCH_SIZE)
train_ds = train_ds.shuffle(BUFFER_SIZE).repeat().batch(BATCH_SIZE)

# %% [markdown]
# ### Model

# %%
lr_schedule = tf.keras.optimizers.schedules.InverseTimeDecay(
  0.001,
  decay_steps=STEPS_PER_EPOCH*1000,
  decay_rate=1,
  staircase=False)

def get_optimizer():
    return tf.keras.optimizers.Adam(lr_schedule)

# %%
step = np.linspace(0,100000)
lr = lr_schedule(step)
plt.figure(figsize = (8,6))
plt.plot(step/STEPS_PER_EPOCH, lr)
plt.ylim([0,max(plt.ylim())])
plt.xlabel('Epoch')
_ = plt.ylabel('Learning Rate')

# %%
def get_callbacks(name):
    return [
        tfdocs.modeling.EpochDots(),
        tf.keras.callbacks.EarlyStopping(monitor='val_binary_crossentropy', patience=200),
        tf.keras.callbacks.TensorBoard(logdir/name),
        ]

# %%
def compile_and_fit(model, name, optimizer=None, max_epochs=10000):
    if optimizer is None:
        optimizer = get_optimizer()
        model.compile(optimizer=optimizer,
                    loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
                    metrics=[
                      tf.keras.losses.BinaryCrossentropy(
                          from_logits=True, name='binary_crossentropy'),
                      'accuracy'])

    model.summary()

    history = model.fit(
    train_ds,
    steps_per_epoch = STEPS_PER_EPOCH,
    epochs=max_epochs,
    validation_data=validate_ds,
    callbacks=get_callbacks(name),
    verbose=0)
    return history

# %%
tiny_model = tf.keras.Sequential([
    layers.Dense(16, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(1)
])

# %%
size_histories = {}
size_histories['Tiny'] = compile_and_fit(tiny_model, 'sizes/Tiny')
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                464
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 481
# Trainable params: 481
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5094,  binary_crossentropy:0.8562,  loss:0.8562,  val_accuracy:0.5140,  val_binary_crossentropy:0.8037,  val_loss:0.8037,
# ....................................................................................................
# Epoch: 100, accuracy:0.5941,  binary_crossentropy:0.6289,  loss:0.6289,  val_accuracy:0.5790,  val_binary_crossentropy:0.6295,  val_loss:0.6295,
# ....................................................................................................
# Epoch: 200, accuracy:0.6149,  binary_crossentropy:0.6164,  loss:0.6164,  val_accuracy:0.5960,  val_binary_crossentropy:0.6213,  val_loss:0.6213,
# ....................................................................................................
# Epoch: 300, accuracy:0.6283,  binary_crossentropy:0.6057,  loss:0.6057,  val_accuracy:0.6290,  val_binary_crossentropy:0.6067,  val_loss:0.6067,
# ....................................................................................................
# Epoch: 400, accuracy:0.6479,  binary_crossentropy:0.5968,  loss:0.5968,  val_accuracy:0.6310,  val_binary_crossentropy:0.5981,  val_loss:0.5981,
# ....................................................................................................
# Epoch: 500, accuracy:0.6606,  binary_crossentropy:0.5897,  loss:0.5897,  val_accuracy:0.6450,  val_binary_crossentropy:0.5896,  val_loss:0.5896,
# ....................................................................................................
# Epoch: 600, accuracy:0.6653,  binary_crossentropy:0.5855,  loss:0.5855,  val_accuracy:0.6380,  val_binary_crossentropy:0.5870,  val_loss:0.5870,
# ....................................................................................................
# Epoch: 700, accuracy:0.6679,  binary_crossentropy:0.5826,  loss:0.5826,  val_accuracy:0.6550,  val_binary_crossentropy:0.5841,  val_loss:0.5841,
# ....................................................................................................
# Epoch: 800, accuracy:0.6717,  binary_crossentropy:0.5796,  loss:0.5796,  val_accuracy:0.6680,  val_binary_crossentropy:0.5819,  val_loss:0.5819,
# ....................................................................................................
# Epoch: 900, accuracy:0.6766,  binary_crossentropy:0.5774,  loss:0.5774,  val_accuracy:0.6690,  val_binary_crossentropy:0.5801,  val_loss:0.5801,
# ....................................................................................................
# Epoch: 1000, accuracy:0.6755,  binary_crossentropy:0.5754,  loss:0.5754,  val_accuracy:0.6760,  val_binary_crossentropy:0.5792,  val_loss:0.5792,
# ....................................................................................................
# Epoch: 1100, accuracy:0.6782,  binary_crossentropy:0.5740,  loss:0.5740,  val_accuracy:0.6770,  val_binary_crossentropy:0.5793,  val_loss:0.5793,
# ....................................................................................................
# Epoch: 1200, accuracy:0.6815,  binary_crossentropy:0.5729,  loss:0.5729,  val_accuracy:0.6600,  val_binary_crossentropy:0.5824,  val_loss:0.5824,
# ....................................................................................................
# Epoch: 1300, accuracy:0.6842,  binary_crossentropy:0.5717,  loss:0.5717,  val_accuracy:0.6730,  val_binary_crossentropy:0.5790,  val_loss:0.5790,
# ....................................................................................................
# Epoch: 1400, accuracy:0.6793,  binary_crossentropy:0.5709,  loss:0.5709,  val_accuracy:0.6710,  val_binary_crossentropy:0.5791,  val_loss:0.5791,
# ....................................................................................................
# Epoch: 1500, accuracy:0.6843,  binary_crossentropy:0.5695,  loss:0.5695,  val_accuracy:0.6820,  val_binary_crossentropy:0.5781,  val_loss:0.5781,
# ....................................................................................................
# Epoch: 1600, accuracy:0.6876,  binary_crossentropy:0.5684,  loss:0.5684,  val_accuracy:0.6790,  val_binary_crossentropy:0.5774,  val_loss:0.5774,
# ....................................................................................................
# Epoch: 1700, accuracy:0.6844,  binary_crossentropy:0.5677,  loss:0.5677,  val_accuracy:0.6820,  val_binary_crossentropy:0.5778,  val_loss:0.5778,
# ....................................................................................................
# Epoch: 1800, accuracy:0.6826,  binary_crossentropy:0.5669,  loss:0.5669,  val_accuracy:0.6940,  val_binary_crossentropy:0.5747,  val_loss:0.5747,
# ....................................................................................................
# Epoch: 1900, accuracy:0.6853,  binary_crossentropy:0.5662,  loss:0.5662,  val_accuracy:0.6890,  val_binary_crossentropy:0.5747,  val_loss:0.5747,
# ....................................................................................................
# Epoch: 2000, accuracy:0.6878,  binary_crossentropy:0.5663,  loss:0.5663,  val_accuracy:0.6870,  val_binary_crossentropy:0.5747,  val_loss:0.5747,
# ....................................................................................................
# Epoch: 2100, accuracy:0.6843,  binary_crossentropy:0.5650,  loss:0.5650,  val_accuracy:0.6860,  val_binary_crossentropy:0.5742,  val_loss:0.5742,
# ....................................................................................................
# Epoch: 2200, accuracy:0.6926,  binary_crossentropy:0.5649,  loss:0.5649,  val_accuracy:0.6620,  val_binary_crossentropy:0.5776,  val_loss:0.5776,
# ....................................................................................................
# Epoch: 2300, accuracy:0.6907,  binary_crossentropy:0.5643,  loss:0.5643,  val_accuracy:0.6740,  val_binary_crossentropy:0.5761,  val_loss:0.5761,
# ....................................................................................................
# Epoch: 2400, accuracy:0.6874,  binary_crossentropy:0.5634,  loss:0.5634,  val_accuracy:0.6890,  val_binary_crossentropy:0.5730,  val_loss:0.5730,
# ....................................................................................................
# Epoch: 2500, accuracy:0.6904,  binary_crossentropy:0.5631,  loss:0.5631,  val_accuracy:0.6820,  val_binary_crossentropy:0.5733,  val_loss:0.5733,
# ....................................................................................................
# Epoch: 2600, accuracy:0.6902,  binary_crossentropy:0.5630,  loss:0.5630,  val_accuracy:0.6780,  val_binary_crossentropy:0.5738,  val_loss:0.5738,
# ....................................................................................................
# Epoch: 2700, accuracy:0.6881,  binary_crossentropy:0.5622,  loss:0.5622,  val_accuracy:0.6800,  val_binary_crossentropy:0.5721,  val_loss:0.5721,
# ....................................................................................................
# Epoch: 2800, accuracy:0.6930,  binary_crossentropy:0.5618,  loss:0.5618,  val_accuracy:0.6770,  val_binary_crossentropy:0.5736,  val_loss:0.5736,
# ....................................................................................................
# Epoch: 2900, accuracy:0.6932,  binary_crossentropy:0.5615,  loss:0.5615,  val_accuracy:0.6790,  val_binary_crossentropy:0.5738,  val_loss:0.5738,
# ....................................................................................................
# Epoch: 3000, accuracy:0.6928,  binary_crossentropy:0.5609,  loss:0.5609,  val_accuracy:0.6790,  val_binary_crossentropy:0.5733,  val_loss:0.5733,
# ....................................................................................................
# Epoch: 3100, accuracy:0.6980,  binary_crossentropy:0.5606,  loss:0.5606,  val_accuracy:0.6780,  val_binary_crossentropy:0.5733,  val_loss:0.5733,
# ....................................................................................................
# Epoch: 3200, accuracy:0.6958,  binary_crossentropy:0.5602,  loss:0.5602,  val_accuracy:0.6790,  val_binary_crossentropy:0.5715,  val_loss:0.5715,
# ....................................................................................................
# Epoch: 3300, accuracy:0.6969,  binary_crossentropy:0.5601,  loss:0.5601,  val_accuracy:0.6760,  val_binary_crossentropy:0.5727,  val_loss:0.5727,
# ....................................................................................................
# Epoch: 3400, accuracy:0.6970,  binary_crossentropy:0.5599,  loss:0.5599,  val_accuracy:0.6810,  val_binary_crossentropy:0.5714,  val_loss:0.5714,
# ....................................................................................................
# Epoch: 3500, accuracy:0.6976,  binary_crossentropy:0.5595,  loss:0.5595,  val_accuracy:0.6840,  val_binary_crossentropy:0.5715,  val_loss:0.5715,
# ....................................................................................................
# Epoch: 3600, accuracy:0.6937,  binary_crossentropy:0.5593,  loss:0.5593,  val_accuracy:0.6880,  val_binary_crossentropy:0.5697,  val_loss:0.5697,
# ....................................................................................................
# Epoch: 3700, accuracy:0.6945,  binary_crossentropy:0.5590,  loss:0.5590,  val_accuracy:0.6860,  val_binary_crossentropy:0.5696,  val_loss:0.5696,
# ....................................................................................................
# Epoch: 3800, accuracy:0.6996,  binary_crossentropy:0.5587,  loss:0.5587,  val_accuracy:0.6800,  val_binary_crossentropy:0.5713,  val_loss:0.5713,
# ....................................................................................................
# Epoch: 3900, accuracy:0.6986,  binary_crossentropy:0.5584,  loss:0.5584,  val_accuracy:0.6760,  val_binary_crossentropy:0.5719,  val_loss:0.5719,
# ....................................................................................................
# Epoch: 4000, accuracy:0.6999,  binary_crossentropy:0.5582,  loss:0.5582,  val_accuracy:0.6770,  val_binary_crossentropy:0.5717,  val_loss:0.5717,
# ....................................................................................................
# Epoch: 4100, accuracy:0.6964,  binary_crossentropy:0.5579,  loss:0.5579,  val_accuracy:0.6840,  val_binary_crossentropy:0.5695,  val_loss:0.5695,
# ....................................................................................................
# Epoch: 4200, accuracy:0.6993,  binary_crossentropy:0.5576,  loss:0.5576,  val_accuracy:0.6840,  val_binary_crossentropy:0.5695,  val_loss:0.5695,
# ....................................................................................................
# Epoch: 4300, accuracy:0.6984,  binary_crossentropy:0.5575,  loss:0.5575,  val_accuracy:0.6860,  val_binary_crossentropy:0.5687,  val_loss:0.5687,
# ....................................................................................................
# Epoch: 4400, accuracy:0.6994,  binary_crossentropy:0.5573,  loss:0.5573,  val_accuracy:0.6830,  val_binary_crossentropy:0.5692,  val_loss:0.5692,
# ....................................................................................................
# Epoch: 4500, accuracy:0.6950,  binary_crossentropy:0.5574,  loss:0.5574,  val_accuracy:0.6910,  val_binary_crossentropy:0.5681,  val_loss:0.5681,
# ....................................................................................................
# Epoch: 4600, accuracy:0.7001,  binary_crossentropy:0.5568,  loss:0.5568,  val_accuracy:0.6820,  val_binary_crossentropy:0.5696,  val_loss:0.5696,
# ....................................................................................................
# Epoch: 4700, accuracy:0.7034,  binary_crossentropy:0.5575,  loss:0.5575,  val_accuracy:0.6800,  val_binary_crossentropy:0.5703,  val_loss:0.5703,
# ....................................................................................................
# Epoch: 4800, accuracy:0.6995,  binary_crossentropy:0.5563,  loss:0.5563,  val_accuracy:0.6840,  val_binary_crossentropy:0.5685,  val_loss:0.5685,
# ....................................................................................................
# Epoch: 4900, accuracy:0.7003,  binary_crossentropy:0.5565,  loss:0.5565,  val_accuracy:0.6900,  val_binary_crossentropy:0.5682,  val_loss:0.5682,
# ....................................................................................................
# Epoch: 5000, accuracy:0.6992,  binary_crossentropy:0.5560,  loss:0.5560,  val_accuracy:0.6890,  val_binary_crossentropy:0.5677,  val_loss:0.5677,
# ....................................................................................................
# Epoch: 5100, accuracy:0.7002,  binary_crossentropy:0.5558,  loss:0.5558,  val_accuracy:0.6900,  val_binary_crossentropy:0.5680,  val_loss:0.5680,
# ....................................................................................................
# Epoch: 5200, accuracy:0.7010,  binary_crossentropy:0.5556,  loss:0.5556,  val_accuracy:0.6860,  val_binary_crossentropy:0.5681,  val_loss:0.5681,
# ....................................................................................................
# Epoch: 5300, accuracy:0.7027,  binary_crossentropy:0.5555,  loss:0.5555,  val_accuracy:0.6870,  val_binary_crossentropy:0.5677,  val_loss:0.5677,
# ....................................................................................................
# Epoch: 5400, accuracy:0.6994,  binary_crossentropy:0.5554,  loss:0.5554,  val_accuracy:0.6890,  val_binary_crossentropy:0.5676,  val_loss:0.5676,
# ....................................................................................................
# Epoch: 5500, accuracy:0.6987,  binary_crossentropy:0.5552,  loss:0.5552,  val_accuracy:0.6890,  val_binary_crossentropy:0.5682,  val_loss:0.5682,
# ....................................................................................................
# Epoch: 5600, accuracy:0.6999,  binary_crossentropy:0.5551,  loss:0.5551,  val_accuracy:0.6910,  val_binary_crossentropy:0.5671,  val_loss:0.5671,
# ........................................................

# %%
plotter = tfdocs.plots.HistoryPlotter(metric = 'binary_crossentropy', smoothing_std=10)
plotter.plot(size_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)

# %%
small_model = tf.keras.Sequential([
    # `input_shape` is only required here so that `.summary` works.
    layers.Dense(16, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(16, activation='elu'),
    layers.Dense(1)
])

# %%
size_histories['Small'] = compile_and_fit(small_model, 'sizes/Small')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 16)                464
#
#  dense_3 (Dense)             (None, 16)                272
#
#  dense_4 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 753
# Trainable params: 753
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4855,  binary_crossentropy:0.7315,  loss:0.7315,  val_accuracy:0.4900,  val_binary_crossentropy:0.7052,  val_loss:0.7052,
# ....................................................................................................
# Epoch: 100, accuracy:0.6409,  binary_crossentropy:0.6068,  loss:0.6068,  val_accuracy:0.6090,  val_binary_crossentropy:0.6199,  val_loss:0.6199,
# ....................................................................................................
# Epoch: 200, accuracy:0.6661,  binary_crossentropy:0.5848,  loss:0.5848,  val_accuracy:0.6530,  val_binary_crossentropy:0.5988,  val_loss:0.5988,
# ....................................................................................................
# Epoch: 300, accuracy:0.6807,  binary_crossentropy:0.5745,  loss:0.5745,  val_accuracy:0.6500,  val_binary_crossentropy:0.5979,  val_loss:0.5979,
# ....................................................................................................
# Epoch: 400, accuracy:0.6872,  binary_crossentropy:0.5678,  loss:0.5678,  val_accuracy:0.6380,  val_binary_crossentropy:0.6052,  val_loss:0.6052,
# ....................................................

# %%
medium_model = tf.keras.Sequential([
    layers.Dense(64, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(64, activation='elu'),
    layers.Dense(64, activation='elu'),
    layers.Dense(1)
])

# %%
size_histories['Medium'] = compile_and_fit(small_model, 'sizes/Medium')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 16)                464
#
#  dense_3 (Dense)             (None, 16)                272
#
#  dense_4 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 753
# Trainable params: 753
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.6848,  binary_crossentropy:0.5662,  loss:0.5662,  val_accuracy:0.6550,  val_binary_crossentropy:0.6029,  val_loss:0.6029,
# ....................................................................................................
# Epoch: 100, accuracy:0.6948,  binary_crossentropy:0.5590,  loss:0.5590,  val_accuracy:0.6390,  val_binary_crossentropy:0.6148,  val_loss:0.6148,
# ....................................................................................................
# Epoch: 200, accuracy:0.6986,  binary_crossentropy:0.5519,  loss:0.5519,  val_accuracy:0.6540,  val_binary_crossentropy:0.6088,  val_loss:0.6088,
# ....................

# %%
large_model = tf.keras.Sequential([
    layers.Dense(512, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(512, activation='elu'),
    layers.Dense(512, activation='elu'),
    layers.Dense(512, activation='elu'),
    layers.Dense(1)
])

# %%
size_histories['large'] = compile_and_fit(large_model, "sizes/large")
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 512)               14848
#
#  dense_10 (Dense)            (None, 512)               262656
#
#  dense_11 (Dense)            (None, 512)               262656
#
#  dense_12 (Dense)            (None, 512)               262656
#
#  dense_13 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5090,  binary_crossentropy:0.8003,  loss:0.8003,  val_accuracy:0.4810,  val_binary_crossentropy:0.6877,  val_loss:0.6877,
# ....................................................................................................
# Epoch: 100, accuracy:1.0000,  binary_crossentropy:0.0021,  loss:0.0021,  val_accuracy:0.6650,  val_binary_crossentropy:1.7736,  val_loss:1.7736,
# ....................................................................................................
# Epoch: 200, accuracy:1.0000,  binary_crossentropy:0.0001,  loss:0.0001,  val_accuracy:0.6610,  val_binary_crossentropy:2.4160,  val_loss:2.4160,
# ....................

# %%
plotter.plot(size_histories)
a = plt.xscale('log')
plt.xlim([5, max(plt.xlim())])
plt.ylim([0.5, 0.7])
plt.xlabel("Epochs [Log Scale]")
# Out:
# Text(0.5, 0, 'Epochs [Log Scale]')

# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard

# Open an embedded TensorBoard viewer
# %tensorboard --logdir {logdir}/sizes
# Out:
#       <iframe id="tensorboard-frame-9b6292e3195282b0" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-9b6292e3195282b0");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ### Strategies to avoid overfitting

# %%
shutil.rmtree(logdir/'regularizers/Tiny', ignore_errors=True)
shutil.copytree(logdir/'sizes/Tiny', logdir/'regularizers/Tiny')
# Out:
# PosixPath('/var/folders/zf/p75y8jj52c72dh5cv6ys92pm0000gn/T/tmpbgjy1ewz/tensorboard_logs/regularizers/Tiny')

# %%
regularizer_histories = {}
regularizer_histories['Tiny'] = size_histories['Tiny']

# %%
l2_model = tf.keras.Sequential([
    layers.Dense(512, activation='elu',
                 kernel_regularizer=regularizers.l2(0.001),
                 input_shape=(FEATURES,)),
    layers.Dense(512, activation='elu',
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(512, activation='elu',
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(512, activation='elu',
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(1)
])

regularizer_histories['l2'] = compile_and_fit(l2_model, "regularizers/l2")
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_14 (Dense)            (None, 512)               14848
#
#  dense_15 (Dense)            (None, 512)               262656
#
#  dense_16 (Dense)            (None, 512)               262656
#
#  dense_17 (Dense)            (None, 512)               262656
#
#  dense_18 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5045,  binary_crossentropy:0.8372,  loss:2.3620,  val_accuracy:0.4600,  val_binary_crossentropy:0.6969,  val_loss:2.1478,
# ....................................................................................................
# Epoch: 100, accuracy:0.6561,  binary_crossentropy:0.5965,  loss:0.6205,  val_accuracy:0.6250,  val_binary_crossentropy:0.5883,  val_loss:0.6124,
# ....................................................................................................
# Epoch: 200, accuracy:0.6776,  binary_crossentropy:0.5809,  loss:0.6052,  val_accuracy:0.6790,  val_binary_crossentropy:0.5757,  val_loss:0.5998,
# ....................................................................................................
# Epoch: 300, accuracy:0.6797,  binary_crossentropy:0.5720,  loss:0.5965,  val_accuracy:0.6600,  val_binary_crossentropy:0.5789,  val_loss:0.6034,
# ....................................................................................................
# Epoch: 400, accuracy:0.6889,  binary_crossentropy:0.5641,  loss:0.5902,  val_accuracy:0.6660,  val_binary_crossentropy:0.5780,  val_loss:0.6042,
# ....................................................................................................
# Epoch: 500, accuracy:0.6843,  binary_crossentropy:0.5649,  loss:0.6001,  val_accuracy:0.6930,  val_binary_crossentropy:0.5749,  val_loss:0.6094,
# .......................................................................................

# %%
plotter.plot(regularizer_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)

# %%
dropout_model = tf.keras.Sequential([
    layers.Dense(512, activation='elu', input_shape=(FEATURES,)),
    layers.Dropout(0.5),
    layers.Dense(512, activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(1)
])

regularizer_histories['dropout'] = compile_and_fit(dropout_model, "regularizers/dropout")
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_19 (Dense)            (None, 512)               14848
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_20 (Dense)            (None, 512)               262656
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_21 (Dense)            (None, 512)               262656
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_22 (Dense)            (None, 512)               262656
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_23 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4970,  binary_crossentropy:0.8178,  loss:0.8178,  val_accuracy:0.4640,  val_binary_crossentropy:0.6932,  val_loss:0.6932,
# ....................................................................................................
# Epoch: 100, accuracy:0.6584,  binary_crossentropy:0.5939,  loss:0.5939,  val_accuracy:0.6600,  val_binary_crossentropy:0.5837,  val_loss:0.5837,
# ....................................................................................................
# Epoch: 200, accuracy:0.6907,  binary_crossentropy:0.5565,  loss:0.5565,  val_accuracy:0.6890,  val_binary_crossentropy:0.5737,  val_loss:0.5737,
# ....................................................................................................
# Epoch: 300, accuracy:0.7205,  binary_crossentropy:0.5077,  loss:0.5077,  val_accuracy:0.6830,  val_binary_crossentropy:0.6018,  val_loss:0.6018,
# ........................................................

# %%
plotter.plot(regularizer_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)

# %%
combined_model = tf.keras.Sequential([
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu', input_shape=(FEATURES,)),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(1)
])

regularizer_histories['combined'] = compile_and_fit(combined_model, "regularizers/combined")
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_24 (Dense)            (None, 512)               14848
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_25 (Dense)            (None, 512)               262656
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_26 (Dense)            (None, 512)               262656
#
#  dropout_6 (Dropout)         (None, 512)               0
#
#  dense_27 (Dense)            (None, 512)               262656
#
#  dropout_7 (Dropout)         (None, 512)               0
#
#  dense_28 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5024,  binary_crossentropy:0.8137,  loss:0.9722,  val_accuracy:0.4780,  val_binary_crossentropy:0.6730,  val_loss:0.8309,
# ....................................................................................................
# Epoch: 100, accuracy:0.6476,  binary_crossentropy:0.6061,  loss:0.6367,  val_accuracy:0.6600,  val_binary_crossentropy:0.5946,  val_loss:0.6250,
# ....................................................................................................
# Epoch: 200, accuracy:0.6650,  binary_crossentropy:0.5896,  loss:0.6149,  val_accuracy:0.6870,  val_binary_crossentropy:0.5700,  val_loss:0.5954,
# ....................................................................................................
# Epoch: 300, accuracy:0.6697,  binary_crossentropy:0.5821,  loss:0.6103,  val_accuracy:0.6890,  val_binary_crossentropy:0.5591,  val_loss:0.5874,
# ....................................................................................................
# Epoch: 400, accuracy:0.6801,  binary_crossentropy:0.5731,  loss:0.6028,  val_accuracy:0.6830,  val_binary_crossentropy:0.5690,  val_loss:0.5987,
# ....................................................................................................
# Epoch: 500, accuracy:0.6781,  binary_crossentropy:0.5722,  loss:0.6039,  val_accuracy:0.6710,  val_binary_crossentropy:0.5508,  val_loss:0.5826,
# ....................................................................................................
# Epoch: 600, accuracy:0.6870,  binary_crossentropy:0.5650,  loss:0.5985,  val_accuracy:0.6850,  val_binary_crossentropy:0.5451,  val_loss:0.5786,
# ....................................................................................................
# Epoch: 700, accuracy:0.6853,  binary_crossentropy:0.5644,  loss:0.5994,  val_accuracy:0.7020,  val_binary_crossentropy:0.5443,  val_loss:0.5792,
# ....................................................................................................
# Epoch: 800, accuracy:0.6922,  binary_crossentropy:0.5624,  loss:0.5984,  val_accuracy:0.6960,  val_binary_crossentropy:0.5430,  val_loss:0.5790,
# ....................................................................................................
# Epoch: 900, accuracy:0.6912,  binary_crossentropy:0.5565,  loss:0.5936,  val_accuracy:0.7020,  val_binary_crossentropy:0.5435,  val_loss:0.5806,
# ...........................................................................

# %%
plotter.plot(regularizer_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)

# %%
# %tensorboard --logdir {logdir}/regularizers
# Out:
#       <iframe id="tensorboard-frame-67b525291387fa1a" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-67b525291387fa1a");
#           const url = new URL("/", window.location);
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
